# %%
import pandas as pd

# %%
app_fb = pd.read_csv("app_feedback_samples.csv")
emails = pd.read_csv("support_emails.csv")
#app_fb
emails
# Out:
#     email_id                     subject  \
# 0          1  Suggestion for Improvement
# 1          2  Suggestion for Improvement
# 2          3  Suggestion for Improvement
# 3          4  Feature Request: Dark Mode
# 4          5            App Crash Report
# 5          6           Data Loss Problem
# 6          7            App Crash Report
# 7          8            App Crash Report
# 8          9                 Login Issue
# 9         10           Data Loss Problem
# 10        11            App Crash Report
# 11        12           Data Loss Problem
# 12        13                 Login Issue
# 13        14                 Login Issue
# 14        15            App Crash Report
# 15        16            App Crash Report
# 16        17  Feature Request: Dark Mode
# 17        18           Data Loss Problem
# 18        19  Feature Request: Dark Mode
# 19        20           Data Loss Problem
# 20        21                 Login Issue
# 21        22  Suggestion for Improvement
# ...
